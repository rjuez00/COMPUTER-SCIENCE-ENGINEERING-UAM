# %% [markdown]
# # Grado en Ingeniería Informática
# ### **Asignatura**: Tratamiento de Señales Visuales/Tratamiento de Señales Multimedia I
# ### Práctica 4: Reconocimiento de escenas con Deep Learning
#
# #### Pregunta 4
#
# ---
#
# Autor: Rodrigo Juez Hernández (rodrigo.juezh@estudiante.uam.es), Universidad Autónoma de Madrid

# %% [markdown]
# # 0. Valores a probar en esta pregunta

# %%
BEST_IMG_SIZE = 224
BEST_BATCH_SIZE = 8 # numero de elementos procesados conjuntamente en cada iteracion
EPOCHS = 25 # numero de epocas para entrenamiento
DATA_AUGMENTATION_TECHNIQUES = ["default", "zoom_range", "rotation", "shift", "all"]

# %% [markdown]
# # 1. Entorno
# (Ejecuta una vez y compacta para que no moleste)

# %% [markdown]
# #### Entorno de trabajo
# Instalación de librerías, comprobación de versiones, carga de dataset y elección de hardware.

# %%
#%%capture
#%tensorflow_version 2.x
# !pip install tensorflow==2.3.0
import tensorflow as tf
import numpy as np
import os, subprocess, pathlib, time
from google.colab import drive
import matplotlib.pyplot as plt

import tensorflow.keras.layers as layers
import tensorflow.keras.models as models
import tensorflow.keras.optimizers as optimizers
# Out:
# Collecting tensorflow==2.3.0
#   Downloading tensorflow-2.3.0-cp37-cp37m-manylinux2010_x86_64.whl (320.4 MB)
#      |████████████████████████████████| 320.4 MB 46 kB/s
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.1.0)
# Collecting h5py<2.11.0,>=2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 37.7 MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.42.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.15.0)
# Collecting tensorflow-estimator<2.4.0,>=2.3.0
#   Downloading tensorflow_estimator-2.3.0-py2.py3-none-any.whl (459 kB)
#      |████████████████████████████████| 459 kB 39.7 MB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (0.12.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (0.2.0)
# Collecting numpy<1.19.0,>=1.16.0
#   Downloading numpy-1.18.5-cp37-cp37m-manylinux1_x86_64.whl (20.1 MB)
#      |████████████████████████████████| 20.1 MB 1.2 MB/s
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (3.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (0.37.0)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (2.7.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.13.3)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.1.2)
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.4.1)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (3.17.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.3.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.23.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (57.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.10.0.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.1.1)
# Installing collected packages: numpy, tensorflow-estimator, h5py, gast, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.7.0
#     Uninstalling tensorflow-estimator-2.7.0:
#       Successfully uninstalled tensorflow-estimator-2.7.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
#       Successfully uninstalled gast-0.4.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.7.0
#     Uninstalling tensorflow-2.7.0:
#       Successfully uninstalled tensorflow-2.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed gast-0.3.3 h5py-2.10.0 numpy-1.18.5 tensorflow-2.3.0 tensorflow-estimator-2.3.0

# %%
# !python --version                     # mostrar version de python
print('Tensorflow ' + tf.__version__) # mostrar version tensorflow


# Montar Google Drive y crear carpetas
drive.mount('/content/gdrive', force_remount=True)

work_dir = '/content/work_dir'                    # directorio de trabajo en local (mas rapido)
dwld_dir = '/content/gdrive/My Drive/dwld_dir'    # directorio de descarga en Google drive personal
subprocess.call(["mkdir","-p",work_dir])          # crear directorio para trabajo
subprocess.call(["mkdir","-p",dwld_dir+'/dataset/'])  # crear directorio para dataset

os.chdir(dwld_dir+'/dataset/')                        # posicionarse en el directorio
# Descargar dataset scenes15 si no esta disponible
if os.path.isfile('./dataset_scenes15.zip') == False: 
  # !wget http://www-vpu.eps.uam.es/~jcs/tsv/dataset_scenes15.zip 
  
# Copiar el dataset al directorio local (mayor velocidad de lectura que en Gdrive)
# !cp /content/gdrive/My\ Drive/dwld_dir/dataset/dataset_scenes15.zip /content/work_dir/

os.chdir(work_dir)                        # posicionarse en el directorio
if os.path.isdir('./scenes15') == False: 
  # !unzip -o -q dataset_scenes15.zip -d .

print('El dataset se encuentra descargado en el directorio {} \ny descomprimido en el directorio {} (usado para lectura de datos)'.format(dwld_dir, work_dir))
# Out:
# Python 3.7.12
# Tensorflow 2.3.0
# Mounted at /content/gdrive
# El dataset se encuentra descargado en el directorio /content/gdrive/My Drive/dwld_dir
# y descomprimido en el directorio /content/work_dir (usado para lectura de datos)

# %%
dataset_dir = pathlib.Path(work_dir + '/scenes15/')

# Obtener etiquetas de clase y numero de clases
CLASS_NAMES = np.array([item.name for item in dataset_dir.glob('*')]) #clases son subdirectorios de '/train/'
NUM_CLASSES = len(CLASS_NAMES) # numero total de clases

# %% [markdown]
# # 2. Preparación pregunta
# Funciones para que instancian el generador, y el modelo para llamarlas reiteradamente.

# %% [markdown]
# #### Preparar dataset

# %%
def generator_dataset(BATCH_SIZE = 16, IMG_HEIGHT = 32, IMG_WIDTH = 32, IMG_CHANNELS = 3, augmentation_technique = "default"):  
  # Crear ImageDataGenerator convirtiendo de uint8 a float32 en el rango [0,1].
  if augmentation_technique == "zoom_range":
      img_gen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, validation_split=0.20, zoom_range = [0.5, 1])

  elif augmentation_technique == "rotation":
     img_gen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, validation_split=0.20, rotation_range = 90)

  elif augmentation_technique == "shift":
     img_gen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, validation_split=0.20,      fill_mode="constant",     width_shift_range = 0.3, height_shift_range = 0.3)

  elif augmentation_technique == "all":
     img_gen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, validation_split=0.20, zoom_range = [0.5, 1], rotation_range = 90,     fill_mode="constant",     width_shift_range = 0.3, height_shift_range = 0.3)

  else:
     img_gen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, validation_split=0.20)

  # Obtenemos un iterador sobre los datos de entrenamiento del dataset
  # aplicando el ImageDataGenerator creado anteriormente

  train_data_gen = img_gen.flow_from_directory(directory=str(dataset_dir),
                                            target_size=(IMG_HEIGHT, IMG_WIDTH),
                                            color_mode='rgb',                                                     
                                            classes = list(CLASS_NAMES),
                                            class_mode='categorical',
                                            batch_size=BATCH_SIZE, 
                                            subset="training",                                         
                                            shuffle=True,
                                            seed=0)

  test_data_gen = img_gen.flow_from_directory(directory=str(dataset_dir),
                                            target_size=(IMG_HEIGHT, IMG_WIDTH),
                                            color_mode='rgb',                                                     
                                            classes = list(CLASS_NAMES),
                                            class_mode='categorical',
                                            batch_size=BATCH_SIZE,
                                            subset="validation",
                                            shuffle=True,
                                            seed=0)
  
  return train_data_gen, test_data_gen

# %% [markdown]
# #### Definir red y optimización

# %%
def model_creation(IMG_HEIGHT = 32, IMG_WIDTH = 32, IMG_CHANNELS = 3, print_summary = False):  
  # definir modelo de red
  model = models.Sequential()

  # incluir capa convolucional C1
  model.add(layers.Conv2D(filters=6, 
                          kernel_size=(3, 3), 
                          strides = (1,1),
                          padding = 'valid',
                          activation='relu', 
                          input_shape=(IMG_HEIGHT,IMG_WIDTH,IMG_CHANNELS)))

  # incluir average pooling S2
  model.add(layers.AveragePooling2D())

  # incluir capa convolucional C3
  model.add(layers.Conv2D(filters=16, 
                          kernel_size=(3, 3),
                          strides = (1,1),
                          padding = 'valid', 
                          activation='relu'))

  # incluir average pooling S4
  model.add(layers.AveragePooling2D())

  # convertir el volumen de datos en vector fila para conectarlo con capa FC
  model.add(layers.Flatten())

  # incluir fully convolutional F5
  model.add(layers.Dense(units=120, activation='relu'))

  # incluir fully convolutional F6
  model.add(layers.Dense(units=84, activation='relu'))

  # incluir salida OUTPUT
  model.add(layers.Dense(units=NUM_CLASSES, activation = 'softmax'))


  # mostar resumen
  if print_summary == True:
    model.summary()


  # definicion con optimizador con valores definidos por el usuario
  LEARNING_RATE = 0.01 # factor de aprendizaje
  model.compile(optimizer=optimizers.SGD(lr=LEARNING_RATE),            
              loss='categorical_crossentropy',            
              metrics=['accuracy'])

  return model

# %% [markdown]
# # 3. Ejecución

# %%
IMG_CHANNELS = 3

test_loss_list = []
test_acc_list = []

train_loss_list = []
train_acc_list = []

test_loss_list = []
test_acc_list = []

train_loss_list = []
train_acc_list = []

history_acc_list = []
history_val_acc_list = []
history_loss_list = []
history_val_loss_list = []

for augmentation_technique in DATA_AUGMENTATION_TECHNIQUES:
  print(f"{'='*10} INICIANDO AUGMENTATION_TECHNIQUE {augmentation_technique} {'='*10}")
  
  model = model_creation(IMG_HEIGHT = BEST_IMG_SIZE, IMG_WIDTH = BEST_IMG_SIZE, IMG_CHANNELS = IMG_CHANNELS, print_summary = False)

  train_data_gen, test_data_gen = generator_dataset(BATCH_SIZE = BEST_BATCH_SIZE, IMG_HEIGHT = BEST_IMG_SIZE, IMG_WIDTH = BEST_IMG_SIZE, IMG_CHANNELS = IMG_CHANNELS, augmentation_technique = augmentation_technique)

  with tf.device('/GPU:0'):
    history = model.fit_generator(
        generator=train_data_gen,          
        steps_per_epoch=train_data_gen.n // BEST_BATCH_SIZE,      
        validation_data=test_data_gen,
        validation_steps=test_data_gen.n // BEST_BATCH_SIZE,
        epochs=EPOCHS,
        verbose=1     
    )


    
  
        
    test_loss, test_acc = model.evaluate_generator( generator=test_data_gen, 
                                                    steps = test_data_gen.n // BEST_BATCH_SIZE, 
                                                    verbose=1)

    train_loss, train_acc = model.evaluate_generator( generator=train_data_gen, 
                                                    steps = train_data_gen.n // BEST_BATCH_SIZE, 
                                                    verbose=1)

  
  test_loss_list.append(test_loss)
  test_acc_list.append(test_acc)

  train_loss_list.append(train_loss)
  train_acc_list.append(train_acc)

  history_acc_list.append(history.history['accuracy']         )
  history_val_acc_list.append(history.history['val_accuracy'] )

  # funcion de perdidas
  history_loss_list.append(history.history['loss']            )
  history_val_loss_list.append(history.history['val_loss']    )
  
  


print("test_loss_list: ", test_loss_list)
print("test_acc_list: ", test_acc_list)

print("train_loss_list: ", train_loss_list)
print("train_acc_list: ", train_acc_list)
# Out:
# ========== INICIANDO AUGMENTATION_TECHNIQUE default ==========
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Epoch 1/25
# 449/449 [==============================] - 17s 39ms/step - loss: 2.6545 - accuracy: 0.1147 - val_loss: 2.5919 - val_accuracy: 0.1644
# Epoch 2/25
# 449/449 [==============================] - 11s 24ms/step - loss: 2.4628 - accuracy: 0.1904 - val_loss: 2.4718 - val_accuracy: 0.2140
# Epoch 3/25
# 449/449 [==============================] - 10s 22ms/step - loss: 2.2854 - accuracy: 0.2478 - val_loss: 2.4143 - val_accuracy: 0.2016
# Epoch 4/25
# 449/449 [==============================] - 10s 22ms/step - loss: 2.1150 - accuracy: 0.3143 - val_loss: 2.2348 - val_accuracy: 0.2714
# Epoch 5/25
# 449/449 [==============================] - 10s 22ms/step - loss: 1.9020 - accuracy: 0.3831 - val_loss: 2.3148 - val_accuracy: 0.3063
# Epoch 6/25
# 449/449 [==============================] - 10s 22ms/step - loss: 1.6693 - accuracy: 0.4702 - val_loss: 2.0601 - val_accuracy: 0.3345
# Epoch 7/25
# 449/449 [==============================] - 10s 21ms/step - loss: 1.2839 - accuracy: 0.5869 - val_loss: 1.9943 - val_accuracy: 0.3795
# Epoch 8/25
# 449/449 [==============================] - 10s 22ms/step - loss: 0.9201 - accuracy: 0.7024 - val_loss: 2.3918 - val_accuracy: 0.3671
# Epoch 9/25
# 449/449 [==============================] - 10s 22ms/step - loss: 0.4413 - accuracy: 0.8644 - val_loss: 2.6715 - val_accuracy: 0.3806
# Epoch 10/25
# 449/449 [==============================] - 10s 22ms/step - loss: 0.1895 - accuracy: 0.9454 - val_loss: 2.7555 - val_accuracy: 0.3626
# Epoch 11/25
# 449/449 [==============================] - 10s 22ms/step - loss: 0.1039 - accuracy: 0.9769 - val_loss: 3.1570 - val_accuracy: 0.4077
# Epoch 12/25
# 449/449 [==============================] - 10s 22ms/step - loss: 0.0397 - accuracy: 0.9900 - val_loss: 3.6499 - val_accuracy: 0.3930
# Epoch 13/25
# 449/449 [==============================] - 10s 22ms/step - loss: 0.0106 - accuracy: 0.9986 - val_loss: 4.0186 - val_accuracy: 0.4032
# Epoch 14/25
# 449/449 [==============================] - 10s 22ms/step - loss: 0.0061 - accuracy: 0.9994 - val_loss: 4.0448 - val_accuracy: 0.4020
# Epoch 15/25
# 449/449 [==============================] - 10s 22ms/step - loss: 0.0035 - accuracy: 0.9997 - val_loss: 4.1775 - val_accuracy: 0.4032
# Epoch 16/25
# 449/449 [==============================] - 10s 22ms/step - loss: 0.0039 - accuracy: 0.9994 - val_loss: 4.1262 - val_accuracy: 0.4167
# Epoch 17/25
# 449/449 [==============================] - 10s 22ms/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 4.2360 - val_accuracy: 0.4144
# Epoch 18/25
# 449/449 [==============================] - 10s 22ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 4.2805 - val_accuracy: 0.4099
# Epoch 19/25
# 449/449 [==============================] - 10s 22ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 4.3618 - val_accuracy: 0.4043
# Epoch 20/25
# 449/449 [==============================] - 10s 22ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 4.3430 - val_accuracy: 0.4189
# Epoch 21/25
# 449/449 [==============================] - 10s 22ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 4.3774 - val_accuracy: 0.4088
# Epoch 22/25
# 449/449 [==============================] - 10s 22ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 4.4261 - val_accuracy: 0.4133
# Epoch 23/25
# 449/449 [==============================] - 10s 22ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 4.4536 - val_accuracy: 0.4122
# Epoch 24/25
# 449/449 [==============================] - 10s 22ms/step - loss: 0.0012 - accuracy: 0.9994 - val_loss: 4.4982 - val_accuracy: 0.4144
# Epoch 25/25
# 449/449 [==============================] - 10s 22ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 4.4758 - val_accuracy: 0.4099
# WARNING:tensorflow:From <ipython-input-12-2edb1812672c>:43: Model.evaluate_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.evaluate, which supports generators.
# 111/111 [==============================] - 2s 15ms/step - loss: 4.4783 - accuracy: 0.4099
# 449/449 [==============================] - 7s 15ms/step - loss: 7.7254e-04 - accuracy: 0.9997
# ========== INICIANDO AUGMENTATION_TECHNIQUE zoom_range ==========
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Epoch 1/25
# 449/449 [==============================] - 56s 125ms/step - loss: 2.6528 - accuracy: 0.1194 - val_loss: 2.6325 - val_accuracy: 0.1329
# Epoch 2/25
# 449/449 [==============================] - 56s 125ms/step - loss: 2.4855 - accuracy: 0.1913 - val_loss: 2.4703 - val_accuracy: 0.2005
# Epoch 3/25
# 449/449 [==============================] - 56s 125ms/step - loss: 2.3661 - accuracy: 0.2308 - val_loss: 2.4677 - val_accuracy: 0.1982
# Epoch 4/25
# 449/449 [==============================] - 56s 125ms/step - loss: 2.2318 - accuracy: 0.2664 - val_loss: 2.3427 - val_accuracy: 0.2500
# Epoch 5/25
# 449/449 [==============================] - 56s 125ms/step - loss: 2.1093 - accuracy: 0.3101 - val_loss: 2.2540 - val_accuracy: 0.2838
# Epoch 6/25
# 449/449 [==============================] - 56s 124ms/step - loss: 2.0299 - accuracy: 0.3366 - val_loss: 2.3539 - val_accuracy: 0.2759
# Epoch 7/25
# 449/449 [==============================] - 56s 125ms/step - loss: 1.9420 - accuracy: 0.3644 - val_loss: 2.1453 - val_accuracy: 0.3018
# Epoch 8/25
# 449/449 [==============================] - 56s 125ms/step - loss: 1.8637 - accuracy: 0.3870 - val_loss: 2.0406 - val_accuracy: 0.3221
# Epoch 9/25
# 449/449 [==============================] - 56s 125ms/step - loss: 1.7963 - accuracy: 0.4140 - val_loss: 2.0570 - val_accuracy: 0.3232
# Epoch 10/25
# 449/449 [==============================] - 56s 124ms/step - loss: 1.7481 - accuracy: 0.4346 - val_loss: 2.0342 - val_accuracy: 0.3592
# Epoch 11/25
# 449/449 [==============================] - 56s 125ms/step - loss: 1.6680 - accuracy: 0.4485 - val_loss: 2.0377 - val_accuracy: 0.3615
# Epoch 12/25
# 449/449 [==============================] - 56s 125ms/step - loss: 1.5878 - accuracy: 0.4747 - val_loss: 1.9909 - val_accuracy: 0.3581
# Epoch 13/25
# 449/449 [==============================] - 56s 125ms/step - loss: 1.5360 - accuracy: 0.4889 - val_loss: 1.9599 - val_accuracy: 0.3705
# Epoch 14/25
# 449/449 [==============================] - 56s 125ms/step - loss: 1.4883 - accuracy: 0.5173 - val_loss: 1.9206 - val_accuracy: 0.3930
# Epoch 15/25
# 449/449 [==============================] - 56s 125ms/step - loss: 1.4107 - accuracy: 0.5331 - val_loss: 1.9866 - val_accuracy: 0.4043
# Epoch 16/25
# 449/449 [==============================] - 56s 125ms/step - loss: 1.3594 - accuracy: 0.5604 - val_loss: 2.1962 - val_accuracy: 0.3863
# Epoch 17/25
# 449/449 [==============================] - 55s 123ms/step - loss: 1.3297 - accuracy: 0.5582 - val_loss: 2.1900 - val_accuracy: 0.3637
# Epoch 18/25
# 449/449 [==============================] - 61s 135ms/step - loss: 1.2606 - accuracy: 0.5863 - val_loss: 2.0719 - val_accuracy: 0.4088
# Epoch 19/25
# 449/449 [==============================] - 55s 122ms/step - loss: 1.2349 - accuracy: 0.5980 - val_loss: 2.0639 - val_accuracy: 0.3941
# Epoch 20/25
# 449/449 [==============================] - 56s 124ms/step - loss: 1.1610 - accuracy: 0.6153 - val_loss: 2.1737 - val_accuracy: 0.3581
# Epoch 21/25
# 449/449 [==============================] - 56s 125ms/step - loss: 1.1443 - accuracy: 0.6250 - val_loss: 2.1803 - val_accuracy: 0.3547
# Epoch 22/25
# 449/449 [==============================] - 55s 122ms/step - loss: 1.0766 - accuracy: 0.6464 - val_loss: 2.0989 - val_accuracy: 0.3998
# Epoch 23/25
# 449/449 [==============================] - 55s 122ms/step - loss: 1.0383 - accuracy: 0.6562 - val_loss: 2.3154 - val_accuracy: 0.3682
# Epoch 24/25
# 449/449 [==============================] - 55s 122ms/step - loss: 0.9893 - accuracy: 0.6754 - val_loss: 2.3342 - val_accuracy: 0.3682
# Epoch 25/25
# 449/449 [==============================] - 55s 123ms/step - loss: 0.9911 - accuracy: 0.6823 - val_loss: 2.1511 - val_accuracy: 0.3908
# 111/111 [==============================] - 11s 95ms/step - loss: 2.0999 - accuracy: 0.4077
# 449/449 [==============================] - 43s 96ms/step - loss: 0.8660 - accuracy: 0.7244
# ========== INICIANDO AUGMENTATION_TECHNIQUE rotation ==========
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Epoch 1/25
# 449/449 [==============================] - 57s 127ms/step - loss: 2.6893 - accuracy: 0.0902 - val_loss: 2.6710 - val_accuracy: 0.1126
# Epoch 2/25
# 449/449 [==============================] - 57s 126ms/step - loss: 2.6215 - accuracy: 0.1267 - val_loss: 2.5784 - val_accuracy: 0.1396
# Epoch 3/25
# 449/449 [==============================] - 57s 127ms/step - loss: 2.5375 - accuracy: 0.1590 - val_loss: 2.5422 - val_accuracy: 0.1599
# Epoch 4/25
# 449/449 [==============================] - 57s 126ms/step - loss: 2.4528 - accuracy: 0.1927 - val_loss: 2.5032 - val_accuracy: 0.1982
# Epoch 5/25
# 449/449 [==============================] - 57s 126ms/step - loss: 2.4015 - accuracy: 0.2088 - val_loss: 2.4540 - val_accuracy: 0.2117
# Epoch 6/25
# 449/449 [==============================] - 57s 126ms/step - loss: 2.3589 - accuracy: 0.2274 - val_loss: 2.4063 - val_accuracy: 0.2196
# Epoch 7/25
# 449/449 [==============================] - 57s 126ms/step - loss: 2.2904 - accuracy: 0.2592 - val_loss: 2.3480 - val_accuracy: 0.2489
# Epoch 8/25
# 449/449 [==============================] - 57s 126ms/step - loss: 2.2218 - accuracy: 0.2706 - val_loss: 2.3054 - val_accuracy: 0.2432
# Epoch 9/25
# 449/449 [==============================] - 57s 126ms/step - loss: 2.1350 - accuracy: 0.2973 - val_loss: 2.3523 - val_accuracy: 0.2455
# Epoch 10/25
# 449/449 [==============================] - 57s 126ms/step - loss: 2.0897 - accuracy: 0.3138 - val_loss: 2.2386 - val_accuracy: 0.2736
# Epoch 11/25
# 449/449 [==============================] - 57s 126ms/step - loss: 2.0450 - accuracy: 0.3321 - val_loss: 2.2673 - val_accuracy: 0.2770
# Epoch 12/25
# 449/449 [==============================] - 57s 126ms/step - loss: 2.0042 - accuracy: 0.3458 - val_loss: 2.3137 - val_accuracy: 0.2714
# Epoch 13/25
# 449/449 [==============================] - 57s 126ms/step - loss: 1.9680 - accuracy: 0.3474 - val_loss: 2.2247 - val_accuracy: 0.2905
# Epoch 14/25
# 449/449 [==============================] - 56s 126ms/step - loss: 1.9282 - accuracy: 0.3703 - val_loss: 2.1619 - val_accuracy: 0.3097
# Epoch 15/25
# 449/449 [==============================] - 56s 125ms/step - loss: 1.8938 - accuracy: 0.3836 - val_loss: 2.0487 - val_accuracy: 0.3491
# Epoch 16/25
# 449/449 [==============================] - 56s 124ms/step - loss: 1.8495 - accuracy: 0.3998 - val_loss: 2.1296 - val_accuracy: 0.3131
# Epoch 17/25
# 449/449 [==============================] - 56s 125ms/step - loss: 1.8190 - accuracy: 0.4037 - val_loss: 2.1270 - val_accuracy: 0.3266
# Epoch 18/25
# 449/449 [==============================] - 56s 125ms/step - loss: 1.8023 - accuracy: 0.4070 - val_loss: 2.0737 - val_accuracy: 0.3221
# Epoch 19/25
# 449/449 [==============================] - 56s 125ms/step - loss: 1.7778 - accuracy: 0.4254 - val_loss: 2.1347 - val_accuracy: 0.2962
# Epoch 20/25
# 449/449 [==============================] - 56s 125ms/step - loss: 1.7496 - accuracy: 0.4229 - val_loss: 2.0915 - val_accuracy: 0.3176
# Epoch 21/25
# 449/449 [==============================] - 56s 126ms/step - loss: 1.7196 - accuracy: 0.4435 - val_loss: 2.0935 - val_accuracy: 0.3457
# Epoch 22/25
# 449/449 [==============================] - 56s 125ms/step - loss: 1.6987 - accuracy: 0.4332 - val_loss: 2.0728 - val_accuracy: 0.3536
# Epoch 23/25
# 449/449 [==============================] - 56s 125ms/step - loss: 1.6934 - accuracy: 0.4346 - val_loss: 1.9754 - val_accuracy: 0.3615
# Epoch 24/25
# 449/449 [==============================] - 56s 124ms/step - loss: 1.6299 - accuracy: 0.4627 - val_loss: 1.9965 - val_accuracy: 0.3525
# Epoch 25/25
# 449/449 [==============================] - 56s 125ms/step - loss: 1.6189 - accuracy: 0.4591 - val_loss: 2.0455 - val_accuracy: 0.3604
# 111/111 [==============================] - 11s 98ms/step - loss: 2.0146 - accuracy: 0.3514
# 449/449 [==============================] - 44s 98ms/step - loss: 1.5294 - accuracy: 0.4964
# ========== INICIANDO AUGMENTATION_TECHNIQUE shift ==========
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Epoch 1/25
# 449/449 [==============================] - 49s 109ms/step - loss: 2.6935 - accuracy: 0.0838 - val_loss: 2.6710 - val_accuracy: 0.1025
# Epoch 2/25
# 449/449 [==============================] - 48s 108ms/step - loss: 2.6506 - accuracy: 0.1111 - val_loss: 2.6339 - val_accuracy: 0.1126
# Epoch 3/25
# 449/449 [==============================] - 48s 108ms/step - loss: 2.5890 - accuracy: 0.1439 - val_loss: 2.5701 - val_accuracy: 0.1441
# Epoch 4/25
# 449/449 [==============================] - 48s 108ms/step - loss: 2.5177 - accuracy: 0.1726 - val_loss: 2.5408 - val_accuracy: 0.1667
# Epoch 5/25
# 449/449 [==============================] - 48s 108ms/step - loss: 2.4164 - accuracy: 0.2077 - val_loss: 2.4018 - val_accuracy: 0.1903
# Epoch 6/25
# 449/449 [==============================] - 49s 108ms/step - loss: 2.2866 - accuracy: 0.2391 - val_loss: 2.3132 - val_accuracy: 0.2309
# Epoch 7/25
# 449/449 [==============================] - 48s 108ms/step - loss: 2.2120 - accuracy: 0.2642 - val_loss: 2.2852 - val_accuracy: 0.2489
# Epoch 8/25
# 449/449 [==============================] - 48s 108ms/step - loss: 2.1392 - accuracy: 0.2798 - val_loss: 2.2994 - val_accuracy: 0.2432
# Epoch 9/25
# 449/449 [==============================] - 48s 108ms/step - loss: 2.1075 - accuracy: 0.2876 - val_loss: 2.5100 - val_accuracy: 0.2309
# Epoch 10/25
# 449/449 [==============================] - 48s 107ms/step - loss: 2.0832 - accuracy: 0.2979 - val_loss: 2.1260 - val_accuracy: 0.2815
# Epoch 11/25
# 449/449 [==============================] - 48s 108ms/step - loss: 2.0482 - accuracy: 0.3124 - val_loss: 2.1234 - val_accuracy: 0.2962
# Epoch 12/25
# 449/449 [==============================] - 48s 108ms/step - loss: 2.0236 - accuracy: 0.3135 - val_loss: 2.0796 - val_accuracy: 0.3086
# Epoch 13/25
# 449/449 [==============================] - 48s 108ms/step - loss: 1.9997 - accuracy: 0.3257 - val_loss: 2.1051 - val_accuracy: 0.2950
# Epoch 14/25
# 449/449 [==============================] - 48s 107ms/step - loss: 1.9718 - accuracy: 0.3427 - val_loss: 2.0169 - val_accuracy: 0.3232
# Epoch 15/25
# 449/449 [==============================] - 48s 107ms/step - loss: 1.9278 - accuracy: 0.3561 - val_loss: 2.0675 - val_accuracy: 0.3412
# Epoch 16/25
# 449/449 [==============================] - 49s 109ms/step - loss: 1.8866 - accuracy: 0.3516 - val_loss: 2.1138 - val_accuracy: 0.3255
# Epoch 17/25
# 449/449 [==============================] - 49s 109ms/step - loss: 1.8731 - accuracy: 0.3747 - val_loss: 1.9874 - val_accuracy: 0.3311
# Epoch 18/25
# 449/449 [==============================] - 49s 108ms/step - loss: 1.8382 - accuracy: 0.3967 - val_loss: 2.0440 - val_accuracy: 0.3074
# Epoch 19/25
# 449/449 [==============================] - 49s 108ms/step - loss: 1.8122 - accuracy: 0.3945 - val_loss: 1.9389 - val_accuracy: 0.3739
# Epoch 20/25
# 449/449 [==============================] - 49s 108ms/step - loss: 1.7856 - accuracy: 0.3998 - val_loss: 1.9741 - val_accuracy: 0.3649
# Epoch 21/25
# 449/449 [==============================] - 48s 107ms/step - loss: 1.7558 - accuracy: 0.4151 - val_loss: 1.8160 - val_accuracy: 0.4043
# Epoch 22/25
# 449/449 [==============================] - 48s 107ms/step - loss: 1.7110 - accuracy: 0.4287 - val_loss: 1.8173 - val_accuracy: 0.3795
# Epoch 23/25
# 449/449 [==============================] - 48s 108ms/step - loss: 1.6699 - accuracy: 0.4340 - val_loss: 1.7564 - val_accuracy: 0.4110
# Epoch 24/25
# 449/449 [==============================] - 48s 108ms/step - loss: 1.6364 - accuracy: 0.4351 - val_loss: 1.7522 - val_accuracy: 0.4223
# Epoch 25/25
# 449/449 [==============================] - 48s 108ms/step - loss: 1.6108 - accuracy: 0.4535 - val_loss: 1.7803 - val_accuracy: 0.4032
# 111/111 [==============================] - 9s 84ms/step - loss: 1.7508 - accuracy: 0.4223
# 449/449 [==============================] - 38s 84ms/step - loss: 1.5073 - accuracy: 0.4903
# ========== INICIANDO AUGMENTATION_TECHNIQUE all ==========
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Epoch 1/25
# 449/449 [==============================] - 52s 115ms/step - loss: 2.6929 - accuracy: 0.0902 - val_loss: 2.6768 - val_accuracy: 0.0845
# Epoch 2/25
# 449/449 [==============================] - 52s 116ms/step - loss: 2.6524 - accuracy: 0.1075 - val_loss: 2.6985 - val_accuracy: 0.0788
# Epoch 3/25
# 449/449 [==============================] - 52s 116ms/step - loss: 2.6301 - accuracy: 0.1236 - val_loss: 2.6105 - val_accuracy: 0.1115
# Epoch 4/25
# 449/449 [==============================] - 52s 115ms/step - loss: 2.5786 - accuracy: 0.1356 - val_loss: 2.5954 - val_accuracy: 0.1160
# Epoch 5/25
# 449/449 [==============================] - 52s 116ms/step - loss: 2.5221 - accuracy: 0.1587 - val_loss: 2.5794 - val_accuracy: 0.1363
# Epoch 6/25
# 449/449 [==============================] - 52s 116ms/step - loss: 2.4804 - accuracy: 0.1748 - val_loss: 2.5111 - val_accuracy: 0.1498
# Epoch 7/25
# 449/449 [==============================] - 52s 116ms/step - loss: 2.4503 - accuracy: 0.1748 - val_loss: 2.4915 - val_accuracy: 0.1554
# Epoch 8/25
# 449/449 [==============================] - 52s 116ms/step - loss: 2.3953 - accuracy: 0.1901 - val_loss: 2.4759 - val_accuracy: 0.1633
# Epoch 9/25
# 449/449 [==============================] - 52s 116ms/step - loss: 2.4076 - accuracy: 0.1890 - val_loss: 2.4648 - val_accuracy: 0.1644
# Epoch 10/25
# 449/449 [==============================] - 52s 116ms/step - loss: 2.3912 - accuracy: 0.2091 - val_loss: 2.4330 - val_accuracy: 0.1971
# Epoch 11/25
# 449/449 [==============================] - 52s 116ms/step - loss: 2.3606 - accuracy: 0.2080 - val_loss: 2.4404 - val_accuracy: 0.1993
# Epoch 12/25
# 449/449 [==============================] - 53s 117ms/step - loss: 2.3558 - accuracy: 0.2085 - val_loss: 2.4143 - val_accuracy: 0.1813
# Epoch 13/25
# 449/449 [==============================] - 52s 117ms/step - loss: 2.3389 - accuracy: 0.2210 - val_loss: 2.4223 - val_accuracy: 0.2061
# Epoch 14/25
# 449/449 [==============================] - 53s 117ms/step - loss: 2.3142 - accuracy: 0.2313 - val_loss: 2.4736 - val_accuracy: 0.1554
# Epoch 15/25
# 449/449 [==============================] - 53s 117ms/step - loss: 2.3020 - accuracy: 0.2311 - val_loss: 2.4799 - val_accuracy: 0.1836
# Epoch 16/25
# 449/449 [==============================] - 53s 117ms/step - loss: 2.3083 - accuracy: 0.2224 - val_loss: 2.3487 - val_accuracy: 0.2185
# Epoch 17/25
# 449/449 [==============================] - 53s 118ms/step - loss: 2.2936 - accuracy: 0.2386 - val_loss: 2.5206 - val_accuracy: 0.1813
# Epoch 18/25
# 449/449 [==============================] - 53s 117ms/step - loss: 2.2853 - accuracy: 0.2322 - val_loss: 2.4158 - val_accuracy: 0.2196
# Epoch 19/25
# 449/449 [==============================] - 52s 116ms/step - loss: 2.2753 - accuracy: 0.2330 - val_loss: 2.3355 - val_accuracy: 0.2320
# Epoch 20/25
# 449/449 [==============================] - 52s 116ms/step - loss: 2.2490 - accuracy: 0.2444 - val_loss: 2.3348 - val_accuracy: 0.2275
# Epoch 21/25
# 449/449 [==============================] - 52s 116ms/step - loss: 2.2402 - accuracy: 0.2511 - val_loss: 2.3534 - val_accuracy: 0.2196
# Epoch 22/25
# 449/449 [==============================] - 52s 116ms/step - loss: 2.2391 - accuracy: 0.2508 - val_loss: 2.3100 - val_accuracy: 0.2309
# Epoch 23/25
# 449/449 [==============================] - 52s 115ms/step - loss: 2.2256 - accuracy: 0.2611 - val_loss: 2.3143 - val_accuracy: 0.2241
# Epoch 24/25
# 449/449 [==============================] - 52s 116ms/step - loss: 2.2038 - accuracy: 0.2642 - val_loss: 2.4361 - val_accuracy: 0.1971
# Epoch 25/25
# 449/449 [==============================] - 52s 116ms/step - loss: 2.1984 - accuracy: 0.2681 - val_loss: 2.3569 - val_accuracy: 0.2005
# 111/111 [==============================] - 10s 91ms/step - loss: 2.2666 - accuracy: 0.2264
# 449/449 [==============================] - 41s 91ms/step - loss: 2.1698 - accuracy: 0.2703
# test_loss_list:  [4.478261947631836, 2.0999040603637695, 2.0145583152770996, 1.7508299350738525, 2.2666099071502686]
# test_acc_list:  [0.4099099040031433, 0.407657653093338, 0.3513513505458832, 0.42229729890823364, 0.22635135054588318]
# train_loss_list:  [0.0007725392351858318, 0.8659511208534241, 1.5294201374053955, 1.5073223114013672, 2.1697580814361572]
# train_acc_list:  [0.9997215867042542, 0.724387526512146, 0.49638083577156067, 0.490256130695343, 0.2703229486942291]

# %% [markdown]
# # 4. Plotting resultados

# %%
ind = np.arange(len(DATA_AUGMENTATION_TECHNIQUES))
width = 0.35 

fig, axs = plt.subplots(2,1)
axs[0].bar(ind, train_acc_list,width,  label='Rendimiento train (accuracy)')
axs[0].bar(ind + width, test_acc_list,width,  label='Rendimiento validacion (accuracy)')
axs[0].legend(loc='upper right')
axs[0].set_title('Training and Validation Accuracy')

axs[0].set_xticks(ind + width / 2)
axs[0].set_xticklabels(DATA_AUGMENTATION_TECHNIQUES)




axs[1].bar(ind, train_loss_list,width,  label='Pérdidas entrenamiento (Loss)')
axs[1].bar(ind + width, test_loss_list,width,  label='Pérdidas validacion (Loss)')
axs[1].legend(loc='upper right')
axs[1].set_title('Training and Validation Loss')

axs[1].set_xticks(ind + width / 2)
axs[1].set_xticklabels(DATA_AUGMENTATION_TECHNIQUES)
axs[1].set_xlabel('Data Augmentation Technique')


fig.set_size_inches(11.5, 11.5)
fig.set_dpi(100)
plt.show()

# %%
fig, axs = plt.subplots(4,1)
epoch_list = np.arange(EPOCHS)

for idx, batch_size in enumerate(DATA_AUGMENTATION_TECHNIQUES):
  axs[0].plot(epoch_list, history_acc_list[idx],  label=f'Data Augmentation {batch_size}')
  axs[0].set_title(f'Training Accuracy')
  axs[0].legend(loc='upper left')

for idx, batch_size in enumerate(DATA_AUGMENTATION_TECHNIQUES):
  axs[1].plot(epoch_list, history_val_acc_list[idx],  label=f'Data Augmentation {batch_size}')
  axs[1].set_title(f'Test Accuracy')
  axs[1].legend(loc='upper left')


for idx, batch_size in enumerate(DATA_AUGMENTATION_TECHNIQUES):
  axs[2].plot(epoch_list, history_loss_list[idx],  label=f'Data Augmentation {batch_size}')
  axs[2].set_title(f'Training Loss')
  axs[2].legend(loc='upper left')


for idx, batch_size in enumerate(DATA_AUGMENTATION_TECHNIQUES):
  axs[3].plot(epoch_list, history_val_loss_list[idx],  label=f'Data Augmentation {batch_size}')
  axs[3].set_title(f'Test Loss')
  axs[3].legend(loc='upper left')


  
  

fig.set_size_inches(11.5, 20)
fig.set_dpi(100)
plt.tight_layout()
plt.xlabel("#EPOCHS")
plt.show()

# %% [markdown]
# Esto lo hago para que no tenga que reejecutar todo simplemente para cambiar el aspecto estético de las gráficas o generar nuevas.

# %%
print("test_loss_list = ", test_loss_list)
print("test_acc_list = ", test_acc_list)

print("train_loss_list = ", train_loss_list)
print("train_acc_list = ", train_acc_list)

print("history_acc_list = ", history_acc_list)
print("history_val_acc_list = ", history_val_acc_list)
print("history_loss_list = ", history_loss_list)
print("history_val_loss_list = ", history_val_loss_list)
# Out:
# test_loss_list =  [4.478261947631836, 2.0999040603637695, 2.0145583152770996, 1.7508299350738525, 2.2666099071502686]
# test_acc_list =  [0.4099099040031433, 0.407657653093338, 0.3513513505458832, 0.42229729890823364, 0.22635135054588318]
# train_loss_list =  [0.0007725392351858318, 0.8659511208534241, 1.5294201374053955, 1.5073223114013672, 2.1697580814361572]
# train_acc_list =  [0.9997215867042542, 0.724387526512146, 0.49638083577156067, 0.490256130695343, 0.2703229486942291]
# history_acc_list =  [[0.1146993339061737, 0.1904231607913971, 0.24777282774448395, 0.31430956721305847, 0.38307350873947144, 0.47021159529685974, 0.5868597030639648, 0.7023941874504089, 0.8644209504127502, 0.9454342722892761, 0.9768930673599243, 0.9899777173995972, 0.9986079931259155, 0.9994432330131531, 0.9997215867042542, 0.9994432330131531, 0.9994432330131531, 0.9994432330131531, 0.9997215867042542, 0.9997215867042542, 0.9997215867042542, 0.9994432330131531, 0.9994432330131531, 0.9994432330131531, 0.9997215867042542], [0.11943206936120987, 0.19125835597515106, 0.2307906448841095, 0.26642540097236633, 0.3101336359977722, 0.336581289768219, 0.36442092061042786, 0.38697105646133423, 0.4139755070209503, 0.4345768392086029, 0.44849666953086853, 0.47466591000556946, 0.48886415362358093, 0.5172605514526367, 0.5331291556358337, 0.5604120492935181, 0.5581848621368408, 0.5863028764724731, 0.5979955196380615, 0.615256130695343, 0.625, 0.6464365124702454, 0.6561803817749023, 0.6753897666931152, 0.682349681854248], [0.09020044654607773, 0.12667037546634674, 0.1589643657207489, 0.19265033304691315, 0.20879732072353363, 0.22744989395141602, 0.25918707251548767, 0.2706013321876526, 0.2973273992538452, 0.31375277042388916, 0.3321269452571869, 0.34576836228370667, 0.3474387526512146, 0.37026727199554443, 0.38363027572631836, 0.39977729320526123, 0.403674840927124, 0.4070155918598175, 0.42538976669311523, 0.4228841960430145, 0.4434855282306671, 0.4331848621368408, 0.4345768392086029, 0.4626948833465576, 0.4590757191181183], [0.08379732817411423, 0.11108017712831497, 0.14393095672130585, 0.17260579764842987, 0.2076837420463562, 0.2391425371170044, 0.2641982138156891, 0.27978840470314026, 0.28758352994918823, 0.2978841960430145, 0.3123607933521271, 0.3134743869304657, 0.3257238268852234, 0.34270602464675903, 0.35606902837753296, 0.35161471366882324, 0.37472161650657654, 0.3967149257659912, 0.39448773860931396, 0.39977729320526123, 0.41508910059928894, 0.4287305176258087, 0.4340200424194336, 0.4351336359977722, 0.45350778102874756], [0.09020044654607773, 0.10746102780103683, 0.12360801547765732, 0.13557906448841095, 0.15868596732616425, 0.17483295500278473, 0.17483295500278473, 0.19014476239681244, 0.189031183719635, 0.2090757191181183, 0.20796214044094086, 0.20851893723011017, 0.22104677557945251, 0.2313474416732788, 0.23106904327869415, 0.2224387526512146, 0.23858574032783508, 0.23218262195587158, 0.23301781713962555, 0.24443207681179047, 0.2511135935783386, 0.2508351802825928, 0.26113584637641907, 0.2641982138156891, 0.2680957615375519]]
# history_val_acc_list =  [[0.1644144207239151, 0.21396397054195404, 0.2015765756368637, 0.2713963985443115, 0.30630630254745483, 0.33445945382118225, 0.3795045018196106, 0.36711710691452026, 0.38063064217567444, 0.36261260509490967, 0.407657653093338, 0.3930180072784424, 0.4031531512737274, 0.40202704071998596, 0.4031531512737274, 0.4166666567325592, 0.4144144058227539, 0.4099099040031433, 0.40427929162979126, 0.4189189076423645, 0.40878379344940186, 0.41328829526901245, 0.4121621549129486, 0.4144144058227539, 0.4099099040031433], [0.13288287818431854, 0.20045045018196106, 0.19819819927215576, 0.25, 0.28378379344940186, 0.2759009003639221, 0.30180180072784424, 0.3220720589160919, 0.32319819927215576, 0.3592342436313629, 0.3614864945411682, 0.3581081032752991, 0.3704954981803894, 0.3930180072784424, 0.40427929162979126, 0.3862612545490265, 0.3637387454509735, 0.40878379344940186, 0.3941441476345062, 0.3581081032752991, 0.3547297418117523, 0.3997747600078583, 0.3682432472705841, 0.3682432472705841, 0.3907657563686371], [0.11261261254549026, 0.13963964581489563, 0.1599099040031433, 0.19819819927215576, 0.21171170473098755, 0.21959459781646729, 0.24887387454509735, 0.2432432472705841, 0.2454954981803894, 0.2736486494541168, 0.27702704071998596, 0.2713963985443115, 0.29054054617881775, 0.309684693813324, 0.3490990996360779, 0.3130630552768707, 0.3265765905380249, 0.3220720589160919, 0.2961711585521698, 0.3175675570964813, 0.34572070837020874, 0.3536036014556885, 0.3614864945411682, 0.352477490901947, 0.36036035418510437], [0.10247747600078583, 0.11261261254549026, 0.14414414763450623, 0.1666666716337204, 0.19031532108783722, 0.23085585236549377, 0.24887387454509735, 0.2432432472705841, 0.23085585236549377, 0.28153154253959656, 0.2961711585521698, 0.30855855345726013, 0.29504504799842834, 0.32319819927215576, 0.34121620655059814, 0.32545045018196106, 0.3310810923576355, 0.3074324429035187, 0.37387385964393616, 0.36486485600471497, 0.40427929162979126, 0.3795045018196106, 0.41103604435920715, 0.42229729890823364, 0.4031531512737274], [0.08445946127176285, 0.078828826546669, 0.11148648709058762, 0.11599098891019821, 0.1362612545490265, 0.14977477490901947, 0.15540540218353271, 0.16328829526901245, 0.1644144207239151, 0.1970720738172531, 0.1993243247270584, 0.18130630254745483, 0.2060810774564743, 0.15540540218353271, 0.18355855345726013, 0.21846847236156464, 0.18130630254745483, 0.21959459781646729, 0.23198197782039642, 0.22747747600078583, 0.21959459781646729, 0.23085585236549377, 0.22409909963607788, 0.1970720738172531, 0.20045045018196106]]
# history_loss_list =  [[2.6545395851135254, 2.462754726409912, 2.2853925228118896, 2.1150059700012207, 1.9020317792892456, 1.6693470478057861, 1.28390634059906, 0.9200859069824219, 0.44127795100212097, 0.18947163224220276, 0.10386183857917786, 0.03971448540687561, 0.010629798285663128, 0.006101701874285936, 0.0035188044421374798, 0.0039035724475979805, 0.00292151584289968, 0.0022946647368371487, 0.0016898163594305515, 0.0013351300731301308, 0.0012585053918883204, 0.0014348194235935807, 0.0013984451070427895, 0.001245088060386479, 0.0010245388839393854], [2.652756452560425, 2.4854750633239746, 2.3661446571350098, 2.2317728996276855, 2.1093361377716064, 2.0299320220947266, 1.9420382976531982, 1.86372971534729, 1.796263337135315, 1.748103380203247, 1.6679869890213013, 1.5877635478973389, 1.5359671115875244, 1.4882746934890747, 1.4107364416122437, 1.359380841255188, 1.3296867609024048, 1.2606289386749268, 1.2348713874816895, 1.1609585285186768, 1.1443397998809814, 1.0766193866729736, 1.0383436679840088, 0.9893112182617188, 0.991057813167572], [2.6893374919891357, 2.6215450763702393, 2.5374722480773926, 2.4527628421783447, 2.401454210281372, 2.3588943481445312, 2.2903530597686768, 2.221839189529419, 2.134988784790039, 2.089672803878784, 2.044968366622925, 2.004232883453369, 1.9679940938949585, 1.9281706809997559, 1.8937817811965942, 1.849461317062378, 1.8190492391586304, 1.8023420572280884, 1.7777740955352783, 1.7496260404586792, 1.7196242809295654, 1.6987354755401611, 1.6933786869049072, 1.629926085472107, 1.6189223527908325], [2.6934924125671387, 2.6505517959594727, 2.5890207290649414, 2.5176589488983154, 2.416389226913452, 2.2865614891052246, 2.2120230197906494, 2.1391515731811523, 2.1074697971343994, 2.0832018852233887, 2.0481762886047363, 2.0235607624053955, 1.999660849571228, 1.9718085527420044, 1.9278324842453003, 1.8865522146224976, 1.8731352090835571, 1.8382024765014648, 1.8121672868728638, 1.785612940788269, 1.7557719945907593, 1.7109867334365845, 1.6698753833770752, 1.6364381313323975, 1.610817313194275], [2.6929097175598145, 2.6524481773376465, 2.63012957572937, 2.5786256790161133, 2.522066831588745, 2.480412244796753, 2.450305938720703, 2.3952629566192627, 2.4076011180877686, 2.3911547660827637, 2.3605597019195557, 2.355821132659912, 2.338850498199463, 2.314178705215454, 2.3020122051239014, 2.3083362579345703, 2.293614387512207, 2.2852842807769775, 2.2753028869628906, 2.249044895172119, 2.240194320678711, 2.2391297817230225, 2.2256264686584473, 2.203840494155884, 2.1983604431152344]]
# history_val_loss_list =  [[2.591881513595581, 2.471845865249634, 2.414344549179077, 2.2348475456237793, 2.3147616386413574, 2.0601086616516113, 1.9942587614059448, 2.3917651176452637, 2.6715047359466553, 2.755478620529175, 3.156998634338379, 3.649940252304077, 4.0185546875, 4.044759273529053, 4.177457332611084, 4.126173973083496, 4.236039638519287, 4.28047513961792, 4.361811637878418, 4.343027114868164, 4.377407550811768, 4.426063537597656, 4.453612327575684, 4.498167991638184, 4.475797653198242], [2.632455587387085, 2.4702811241149902, 2.4676804542541504, 2.3427155017852783, 2.2540056705474854, 2.353879451751709, 2.1452744007110596, 2.0406007766723633, 2.056953191757202, 2.0342156887054443, 2.0377092361450195, 1.9908932447433472, 1.9598636627197266, 1.920624017715454, 1.986617088317871, 2.196197032928467, 2.189958095550537, 2.071948289871216, 2.063894748687744, 2.1736888885498047, 2.1802616119384766, 2.098862886428833, 2.3153939247131348, 2.334205150604248, 2.151110887527466], [2.6709651947021484, 2.578366279602051, 2.542161464691162, 2.5032289028167725, 2.4539525508880615, 2.406313419342041, 2.347992181777954, 2.305368185043335, 2.3523361682891846, 2.238593816757202, 2.2673325538635254, 2.3136990070343018, 2.224705934524536, 2.161853790283203, 2.0486905574798584, 2.1296439170837402, 2.1270394325256348, 2.073674440383911, 2.1347146034240723, 2.0914618968963623, 2.0935189723968506, 2.072800874710083, 1.9753962755203247, 1.99650239944458, 2.0455322265625], [2.6709554195404053, 2.633880615234375, 2.5700936317443848, 2.5408012866973877, 2.4017651081085205, 2.3132002353668213, 2.2851507663726807, 2.299412727355957, 2.5100033283233643, 2.126013994216919, 2.123394727706909, 2.079631805419922, 2.1051292419433594, 2.0169241428375244, 2.0674691200256348, 2.1137688159942627, 1.9873546361923218, 2.043973207473755, 1.9388850927352905, 1.9741042852401733, 1.8159648180007935, 1.8172767162322998, 1.7563884258270264, 1.752193808555603, 1.7802808284759521], [2.6767923831939697, 2.6984903812408447, 2.6105079650878906, 2.595386028289795, 2.5794475078582764, 2.5111465454101562, 2.491481304168701, 2.4759111404418945, 2.4648287296295166, 2.4330389499664307, 2.440370798110962, 2.4143173694610596, 2.4223151206970215, 2.4736452102661133, 2.479888916015625, 2.3487229347229004, 2.5206456184387207, 2.415800094604492, 2.3354833126068115, 2.3347630500793457, 2.3533740043640137, 2.310015916824341, 2.314335823059082, 2.4360859394073486, 2.3569483757019043]]
