# %% [markdown]
# # Grado en Ingeniería Informática
# ### **Asignatura**: Tratamiento de Señales Visuales/Tratamiento de Señales Multimedia I
# ### Práctica 4: Reconocimiento de escenas con Deep Learning
#
# #### Pregunta 3
#
# ---
#
# Autor: Rodrigo Juez Hernández (rodrigo.juezh@estudiante.uam.es), Universidad Autónoma de Madrid

# %% [markdown]
# # 0. Valores a probar en esta pregunta

# %%
BEST_IMG_SIZE = 224
BEST_BATCH_SIZE = 8 # numero de elementos procesados conjuntamente en cada iteracion

EPOCHS = 25 # numero de epocas para entrenamiento
FUNCTIONS_ACTIV = ['relu', 'tanh', 'sigmoid', 'swish']

# %% [markdown]
# # 1. Entorno
# (Ejecuta una vez y compacta para que no moleste)

# %% [markdown]
# #### Entorno de trabajo
# Instalación de librerías, comprobación de versiones, carga de dataset y elección de hardware.

# %%
#%%capture
#%tensorflow_version 2.x
# !pip install tensorflow==2.3.0
import tensorflow as tf
import numpy as np
import os, subprocess, pathlib, time
from google.colab import drive
import matplotlib.pyplot as plt

import tensorflow.keras.layers as layers
import tensorflow.keras.models as models
import tensorflow.keras.optimizers as optimizers
# Out:
# Requirement already satisfied: tensorflow==2.3.0 in /usr/local/lib/python3.7/dist-packages (2.3.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (3.3.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.6.3)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (2.3.0)
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.4.1)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.1.2)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.13.3)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (0.3.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.42.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (0.12.0)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (2.7.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (0.37.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (0.2.0)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.18.5)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (3.17.3)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (2.10.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.15.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (57.4.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.3.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.6.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.8.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.1.1)

# %%
# !python --version                     # mostrar version de python
print('Tensorflow ' + tf.__version__) # mostrar version tensorflow


# Montar Google Drive y crear carpetas
drive.mount('/content/gdrive', force_remount=True)

work_dir = '/content/work_dir'                    # directorio de trabajo en local (mas rapido)
dwld_dir = '/content/gdrive/My Drive/dwld_dir'    # directorio de descarga en Google drive personal
subprocess.call(["mkdir","-p",work_dir])          # crear directorio para trabajo
subprocess.call(["mkdir","-p",dwld_dir+'/dataset/'])  # crear directorio para dataset

os.chdir(dwld_dir+'/dataset/')                        # posicionarse en el directorio
# Descargar dataset scenes15 si no esta disponible
if os.path.isfile('./dataset_scenes15.zip') == False: 
  # !wget http://www-vpu.eps.uam.es/~jcs/tsv/dataset_scenes15.zip 
  
# Copiar el dataset al directorio local (mayor velocidad de lectura que en Gdrive)
# !cp /content/gdrive/My\ Drive/dwld_dir/dataset/dataset_scenes15.zip /content/work_dir/

os.chdir(work_dir)                        # posicionarse en el directorio
if os.path.isdir('./scenes15') == False: 
  # !unzip -o -q dataset_scenes15.zip -d .

print('El dataset se encuentra descargado en el directorio {} \ny descomprimido en el directorio {} (usado para lectura de datos)'.format(dwld_dir, work_dir))
# Out:
# Python 3.7.12
# Tensorflow 2.3.0
# Mounted at /content/gdrive
# El dataset se encuentra descargado en el directorio /content/gdrive/My Drive/dwld_dir
# y descomprimido en el directorio /content/work_dir (usado para lectura de datos)

# %%
dataset_dir = pathlib.Path(work_dir + '/scenes15/')

# Obtener etiquetas de clase y numero de clases
CLASS_NAMES = np.array([item.name for item in dataset_dir.glob('*')]) #clases son subdirectorios de '/train/'
NUM_CLASSES = len(CLASS_NAMES) # numero total de clases

# %% [markdown]
# # 2. Preparación pregunta
# Funciones para que instancian el generador, y el modelo para llamarlas reiteradamente.

# %% [markdown]
# #### Preparar dataset

# %%
def generator_dataset(BATCH_SIZE=16, IMG_HEIGHT=32, IMG_WIDTH=32, IMG_CHANNELS=3):  
  # Crear ImageDataGenerator convirtiendo de uint8 a float32 en el rango [0,1].
  img_gen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, validation_split=0.20)

  # Obtenemos un iterador sobre los datos de entrenamiento del dataset
  # aplicando el ImageDataGenerator creado anteriormente

  train_data_gen = img_gen.flow_from_directory(directory=str(dataset_dir),
                                            target_size=(IMG_HEIGHT, IMG_WIDTH),
                                            color_mode='rgb',                                                     
                                            classes = list(CLASS_NAMES),
                                            class_mode='categorical',
                                            batch_size=BATCH_SIZE, 
                                            subset="training",                                         
                                            shuffle=True,
                                            seed=0)

  test_data_gen = img_gen.flow_from_directory(directory=str(dataset_dir),
                                            target_size=(IMG_HEIGHT, IMG_WIDTH),
                                            color_mode='rgb',                                                     
                                            classes = list(CLASS_NAMES),
                                            class_mode='categorical',
                                            batch_size=BATCH_SIZE,
                                            subset="validation",
                                            shuffle=True,
                                            seed=0)
  
  return train_data_gen, test_data_gen

# %% [markdown]
# #### Definir red y optimización

# %%
def model_creation(IMG_HEIGHT = 32, IMG_WIDTH = 32, IMG_CHANNELS = 3, ACTIVATION = "relu", print_summary = False):  
  # definir modelo de red
  model = models.Sequential()

  # incluir capa convolucional C1
  model.add(layers.Conv2D(filters=6, 
                          kernel_size=(3, 3), 
                          strides = (1,1),
                          padding = 'valid',
                          activation=ACTIVATION, 
                          input_shape=(IMG_HEIGHT,IMG_WIDTH,IMG_CHANNELS)))

  # incluir average pooling S2
  model.add(layers.AveragePooling2D())

  # incluir capa convolucional C3
  model.add(layers.Conv2D(filters=16, 
                          kernel_size=(3, 3),
                          strides = (1,1),
                          padding = 'valid', 
                          activation=ACTIVATION))

  # incluir average pooling S4
  model.add(layers.AveragePooling2D())

  # convertir el volumen de datos en vector fila para conectarlo con capa FC
  model.add(layers.Flatten())

  # incluir fully convolutional F5
  model.add(layers.Dense(units=120, activation=ACTIVATION))

  # incluir fully convolutional F6
  model.add(layers.Dense(units=84, activation=ACTIVATION))

  # incluir salida OUTPUT
  model.add(layers.Dense(units=NUM_CLASSES, activation = 'softmax'))


  # mostar resumen
  if print_summary == True:
    model.summary()


  # definicion con optimizador con valores definidos por el usuario
  LEARNING_RATE = 0.01 # factor de aprendizaje
  model.compile(optimizer=optimizers.SGD(lr=LEARNING_RATE),            
              loss='categorical_crossentropy',            
              metrics=['accuracy'])

  return model

# %% [markdown]
# # 3. Ejecución

# %%
# Inicialización de las variables
test_loss_list = []
test_acc_list = []

train_loss_list = []
train_acc_list = []

history_acc_list = []
history_val_acc_list = []
history_loss_list = []
history_val_loss_list = []

# Proceso en cada iteracion
for activation in FUNCTIONS_ACTIV:
  print(f"{'='*10} INICIANDO ACTIVACION {activation} {'='*10}")
  # Se genera el modelo
  model = model_creation(IMG_HEIGHT=BEST_IMG_SIZE,
                         IMG_WIDTH=BEST_IMG_SIZE,
                         ACTIVATION=activation)
  # Se generan los datasets del train y del test
  train_data_gen, test_data_gen = generator_dataset(BATCH_SIZE=BEST_BATCH_SIZE,
                                                    IMG_HEIGHT=BEST_IMG_SIZE,
                                                    IMG_WIDTH=BEST_IMG_SIZE)
  # Entrenamos
  with tf.device('/GPU:0'):
    history = model.fit_generator(
        generator=train_data_gen,          
        steps_per_epoch=train_data_gen.n // BEST_BATCH_SIZE,      
        validation_data=test_data_gen,
        validation_steps=test_data_gen.n // BEST_BATCH_SIZE,
        epochs=EPOCHS,
        verbose=1     
    )


    # Evaluamos y obtenemos el accuracy y el loss del testData
    test_loss, test_acc = model.evaluate_generator(generator=test_data_gen, 
                                                  steps=test_data_gen.n // BEST_BATCH_SIZE, 
                                                  verbose=1)
    
    train_loss, train_acc = model.evaluate_generator( generator=train_data_gen, 
                                                      steps = train_data_gen.n // BEST_BATCH_SIZE, 
                                                      verbose=1)

  
  test_loss_list.append(test_loss)
  test_acc_list.append(test_acc)

  train_loss_list.append(train_loss)
  train_acc_list.append(train_acc)

  # rendimiento
  history_acc_list.append(history.history['accuracy']         )
  history_val_acc_list.append(history.history['val_accuracy'] )

  # funcion de perdidas
  history_loss_list.append(history.history['loss']            )
  history_val_loss_list.append(history.history['val_loss']    )

  print("test_loss: ", test_loss)
  print("test_acc: ", test_acc)

  print("train_loss: ", train_loss)
  print("train_acc: ", train_acc)
# Out:
# ========== INICIANDO ACTIVACION relu ==========
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Epoch 1/25
# 449/449 [==============================] - 26s 58ms/step - loss: 2.6522 - accuracy: 0.1116 - val_loss: 2.6113 - val_accuracy: 0.1239
# Epoch 2/25
# 449/449 [==============================] - 18s 41ms/step - loss: 2.4300 - accuracy: 0.2066 - val_loss: 2.4628 - val_accuracy: 0.2466
# Epoch 3/25
# 449/449 [==============================] - 11s 24ms/step - loss: 2.2628 - accuracy: 0.2634 - val_loss: 2.3381 - val_accuracy: 0.2556
# Epoch 4/25
# 449/449 [==============================] - 11s 24ms/step - loss: 2.0593 - accuracy: 0.3338 - val_loss: 2.1726 - val_accuracy: 0.3255
# Epoch 5/25
# 449/449 [==============================] - 11s 24ms/step - loss: 1.8001 - accuracy: 0.4168 - val_loss: 2.1256 - val_accuracy: 0.3153
# Epoch 6/25
# 449/449 [==============================] - 11s 24ms/step - loss: 1.4369 - accuracy: 0.5373 - val_loss: 2.0165 - val_accuracy: 0.3773
# Epoch 7/25
# 449/449 [==============================] - 11s 24ms/step - loss: 1.0439 - accuracy: 0.6748 - val_loss: 2.0220 - val_accuracy: 0.3818
# Epoch 8/25
# 449/449 [==============================] - 11s 24ms/step - loss: 0.5885 - accuracy: 0.8199 - val_loss: 2.2839 - val_accuracy: 0.4155
# Epoch 9/25
# 449/449 [==============================] - 11s 24ms/step - loss: 0.3529 - accuracy: 0.8928 - val_loss: 2.8862 - val_accuracy: 0.3908
# Epoch 10/25
# 449/449 [==============================] - 12s 27ms/step - loss: 0.1380 - accuracy: 0.9646 - val_loss: 2.9230 - val_accuracy: 0.4167
# Epoch 11/25
# 449/449 [==============================] - 11s 23ms/step - loss: 0.1320 - accuracy: 0.9666 - val_loss: 3.0379 - val_accuracy: 0.4122
# Epoch 12/25
# 449/449 [==============================] - 11s 24ms/step - loss: 0.0555 - accuracy: 0.9883 - val_loss: 3.8959 - val_accuracy: 0.3941
# Epoch 13/25
# 449/449 [==============================] - 11s 24ms/step - loss: 0.2607 - accuracy: 0.9357 - val_loss: 2.7572 - val_accuracy: 0.3986
# Epoch 14/25
# 449/449 [==============================] - 11s 26ms/step - loss: 0.0609 - accuracy: 0.9889 - val_loss: 3.5312 - val_accuracy: 0.4167
# Epoch 15/25
# 449/449 [==============================] - 11s 25ms/step - loss: 0.0113 - accuracy: 0.9986 - val_loss: 3.9541 - val_accuracy: 0.4189
# Epoch 16/25
# 449/449 [==============================] - 11s 25ms/step - loss: 0.0063 - accuracy: 0.9992 - val_loss: 4.1273 - val_accuracy: 0.4065
# Epoch 17/25
# 449/449 [==============================] - 11s 25ms/step - loss: 0.0026 - accuracy: 0.9997 - val_loss: 4.2973 - val_accuracy: 0.4099
# Epoch 18/25
# 449/449 [==============================] - 11s 25ms/step - loss: 0.0030 - accuracy: 0.9997 - val_loss: 4.3465 - val_accuracy: 0.4122
# Epoch 19/25
# 449/449 [==============================] - 11s 24ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 4.4369 - val_accuracy: 0.4077
# Epoch 20/25
# 449/449 [==============================] - 11s 24ms/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 4.3607 - val_accuracy: 0.4144
# Epoch 21/25
# 449/449 [==============================] - 11s 24ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 4.5130 - val_accuracy: 0.4122
# Epoch 22/25
# 449/449 [==============================] - 11s 24ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 4.5242 - val_accuracy: 0.4167
# Epoch 23/25
# 449/449 [==============================] - 11s 25ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 4.5304 - val_accuracy: 0.4200
# Epoch 24/25
# 449/449 [==============================] - 11s 24ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 4.5668 - val_accuracy: 0.4144
# Epoch 25/25
# 449/449 [==============================] - 11s 23ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 4.5933 - val_accuracy: 0.4200
# 111/111 [==============================] - 2s 16ms/step - loss: 4.6026 - accuracy: 0.4200
# 449/449 [==============================] - 7s 17ms/step - loss: 8.6365e-04 - accuracy: 0.9997
# test_loss:  4.602585792541504
# test_acc:  0.42004504799842834
# train_loss:  0.0008636545389890671
# train_acc:  0.9997215867042542
# ========== INICIANDO ACTIVACION tanh ==========
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Epoch 1/25
# 449/449 [==============================] - 11s 24ms/step - loss: 2.5485 - accuracy: 0.1690 - val_loss: 2.5089 - val_accuracy: 0.1700
# Epoch 2/25
# 449/449 [==============================] - 11s 24ms/step - loss: 2.2732 - accuracy: 0.2620 - val_loss: 2.4171 - val_accuracy: 0.2252
# Epoch 3/25
# 449/449 [==============================] - 14s 32ms/step - loss: 2.0919 - accuracy: 0.3346 - val_loss: 2.3730 - val_accuracy: 0.2511
# Epoch 4/25
# 449/449 [==============================] - 17s 38ms/step - loss: 1.9253 - accuracy: 0.3950 - val_loss: 2.3995 - val_accuracy: 0.2421
# Epoch 5/25
# 449/449 [==============================] - 11s 26ms/step - loss: 1.7170 - accuracy: 0.4769 - val_loss: 2.4238 - val_accuracy: 0.2252
# Epoch 6/25
# 449/449 [==============================] - 11s 26ms/step - loss: 1.4545 - accuracy: 0.5718 - val_loss: 2.4681 - val_accuracy: 0.2624
# Epoch 7/25
# 449/449 [==============================] - 11s 25ms/step - loss: 1.1091 - accuracy: 0.7110 - val_loss: 2.6008 - val_accuracy: 0.2477
# Epoch 8/25
# 449/449 [==============================] - 11s 25ms/step - loss: 0.7077 - accuracy: 0.8427 - val_loss: 2.6856 - val_accuracy: 0.2500
# Epoch 9/25
# 449/449 [==============================] - 11s 24ms/step - loss: 0.3800 - accuracy: 0.9374 - val_loss: 2.8984 - val_accuracy: 0.2511
# Epoch 10/25
# 449/449 [==============================] - 11s 24ms/step - loss: 0.1994 - accuracy: 0.9788 - val_loss: 3.0014 - val_accuracy: 0.2432
# Epoch 11/25
# 449/449 [==============================] - 10s 23ms/step - loss: 0.1094 - accuracy: 0.9933 - val_loss: 3.1215 - val_accuracy: 0.2286
# Epoch 12/25
# 449/449 [==============================] - 11s 23ms/step - loss: 0.0697 - accuracy: 0.9975 - val_loss: 3.2089 - val_accuracy: 0.2421
# Epoch 13/25
# 449/449 [==============================] - 11s 24ms/step - loss: 0.0459 - accuracy: 0.9994 - val_loss: 3.2429 - val_accuracy: 0.2376
# Epoch 14/25
# 449/449 [==============================] - 11s 23ms/step - loss: 0.0339 - accuracy: 0.9997 - val_loss: 3.3417 - val_accuracy: 0.2309
# Epoch 15/25
# 449/449 [==============================] - 10s 23ms/step - loss: 0.0269 - accuracy: 0.9997 - val_loss: 3.3735 - val_accuracy: 0.2309
# Epoch 16/25
# 449/449 [==============================] - 10s 23ms/step - loss: 0.0220 - accuracy: 0.9994 - val_loss: 3.4547 - val_accuracy: 0.2320
# Epoch 17/25
# 449/449 [==============================] - 10s 23ms/step - loss: 0.0186 - accuracy: 0.9997 - val_loss: 3.4793 - val_accuracy: 0.2331
# Epoch 18/25
# 449/449 [==============================] - 11s 23ms/step - loss: 0.
# Epoch 8/25
# 449/449 [==============================] - 12s 27ms/step - loss: 0.9282 - accuracy: 0.7127 - val_loss: 2.5909 - val_accuracy: 0.3164
# Epoch 9/25
# 449/449 [==============================] - 12s 27ms/step - loss: 0.4669 - accuracy: 0.8619 - val_loss: 2.7942 - val_accuracy: 0.3243
# Epoch 10/25
# 449/449 [==============================] - 12s 26ms/step - loss: 0.1869 - accuracy: 0.9468 - val_loss: 3.3516 - val_accuracy: 0.3097
# Epoch 11/25
# 449/449 [==============================] - 11s 25ms/step - loss: 0.0703 - accuracy: 0.9836 - val_loss: 3.4627 - val_accuracy: 0.3468
# Epoch 12/25
# 449/449 [==============================] - 11s 24ms/step - loss: 0.0311 - accuracy: 0.9922 - val_loss: 3.4883 - val_accuracy: 0.3604
# Epoch 13/25
# 449/449 [==============================] - 11s 24ms/step - loss: 0.0184 - accuracy: 0.9964 - val_loss: 3.5773 - val_accuracy: 0.3322
# Epoch 14/25
# 449/449 [==============================] - 11s 24ms/step - loss: 0.0117 - accuracy: 0.9975 - val_loss: 3.6042 - val_accuracy: 0.3581
# Epoch 15/25
# 449/449 [==============================] - 11s 25ms/step - loss: 0.0068 - accuracy: 0.9986 - val_loss: 4.0124 - val_accuracy: 0.3671
# Epoch 16/25
# 449/449 [==============================] - 11s 24ms/step - loss: 0.0044 - accuracy: 0.9992 - val_loss: 4.1230 - val_accuracy: 0.3716
# Epoch 17/25
# 449/449 [==============================] - 11s 25ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 4.2076 - val_accuracy: 0.3739
# Epoch 18/25
# 449/449 [==============================] - 11s 25ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 4.3283 - val_accuracy: 0.3682
# Epoch 19/25
# 449/449 [==============================] - 11s 26ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 4.3891 - val_accuracy: 0.3694
# Epoch 20/25
# 449/449 [==============================] - 11s 25ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 4.4643 - val_accuracy: 0.3671
# Epoch 21/25
# 449/449 [==============================] - 11s 24ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 4.5273 - val_accuracy: 0.3649
# Epoch 22/25
# 449/449 [==============================] - 11s 24ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 4.6144 - val_accuracy: 0.3671
# Epoch 23/25
# 449/449 [==============================] - 11s 24ms/step - loss: 0.0012 - accuracy: 0.9994 - val_loss: 4.6299 - val_accuracy: 0.3637
# Epoch 24/25
# 449/449 [==============================] - 11s 25ms/step - loss: 0.0011 - accuracy: 0.9994 - val_loss: 4.7389 - val_accuracy: 0.3604
# Epoch 25/25
# 235/449 [==============>...............] - ETA: 4s - loss: 0.0017 - accuracy: 0.9989

# %% [markdown]
# # 4. Plotting resultados

# %%
"""
history_acc_list = []
history_val_acc_list = []
history_loss_list = []
history_val_loss_list = []
"""

ind = np.arange(len(FUNCTIONS_ACTIV))
width = 0.35 

fig, axs = plt.subplots(2,1)
axs[0].bar(ind, train_acc_list,width,  label='Rendimiento train (accuracy)')
axs[0].bar(ind + width, test_acc_list,width,  label='Rendimiento validacion (accuracy)')
axs[0].legend(loc='upper right')
axs[0].set_title('Training and Validation Accuracy')

axs[0].set_xticks(ind + width / 2)
axs[0].set_xticklabels(FUNCTIONS_ACTIV)




axs[1].bar(ind, train_loss_list,width,  label='Pérdidas entrenamiento (Loss)')
axs[1].bar(ind + width, test_loss_list,width,  label='Pérdidas validacion (Loss)')
axs[1].legend(loc='upper right')
axs[1].set_title('Training and Validation Loss')

axs[1].set_xticks(ind + width / 2)
axs[1].set_xticklabels(FUNCTIONS_ACTIV)
axs[1].set_xlabel('ACTIVATION FUNCTION')


fig.set_size_inches(11.5, 11.5)
fig.set_dpi(100)
plt.show()

# %%
fig, axs = plt.subplots(4,1)
epoch_list = np.arange(EPOCHS)

for idx, batch_size in enumerate(FUNCTIONS_ACTIV):
  axs[0].plot(epoch_list, history_acc_list[idx],  label=f'Batch {batch_size}')
  axs[0].set_title(f'Training Accuracy')
  axs[0].legend(loc='upper left')

for idx, batch_size in enumerate(FUNCTIONS_ACTIV):
  axs[1].plot(epoch_list, history_val_acc_list[idx],  label=f'Batch {batch_size}')
  axs[1].set_title(f'Test Accuracy')
  axs[1].legend(loc='upper left')


for idx, batch_size in enumerate(FUNCTIONS_ACTIV):
  axs[2].plot(epoch_list, history_loss_list[idx],  label=f'Batch {batch_size}')
  axs[2].set_title(f'Training Loss')
  axs[2].legend(loc='upper left')


for idx, batch_size in enumerate(FUNCTIONS_ACTIV):
  axs[3].plot(epoch_list, history_val_loss_list[idx],  label=f'Batch {batch_size}')
  axs[3].set_title(f'Test Loss')
  axs[3].legend(loc='upper left')


  
  

fig.set_size_inches(11.5, 20)
fig.set_dpi(100)
plt.tight_layout()
plt.xlabel("#EPOCHS")
plt.show()

# %%
print("test_loss_list: ", test_loss_list)
print("test_acc_list: ", test_acc_list)

print("train_loss_list: ", train_loss_list)
print("train_acc_list: ", train_acc_list)

print("history_acc_list: ", history_acc_list)
print("history_val_acc_list: ", history_val_acc_list)
print("history_loss_list: ", history_loss_list)
print("history_val_loss_list: ", history_val_loss_list)
# Out:
# test_loss_list:  [4.602585792541504, 3.6398656368255615, 2.69193172454834, 4.733003616333008]
# test_acc_list:  [0.42004504799842834, 0.23310810327529907, 0.078828826546669, 0.3659909963607788]
# train_loss_list:  [0.0008636545389890671, 0.007651425898075104, 2.6915907859802246, 0.0008242159383371472]
# train_acc_list:  [0.9997215867042542, 0.9997215867042542, 0.0801781713962555, 0.9997215867042542]
# history_acc_list:  [[0.11163697391748428, 0.20657014846801758, 0.2633630335330963, 0.3337973356246948, 0.4167594611644745, 0.5373051166534424, 0.6748329401016235, 0.8198775053024292, 0.8928173780441284, 0.964643657207489, 0.9665924310684204, 0.9883073568344116, 0.9356904029846191, 0.9888641238212585, 0.9986079931259155, 0.9991648197174072, 0.9997215867042542, 0.9997215867042542, 0.9997215867042542, 0.9994432330131531, 0.9997215867042542, 0.9997215867042542, 0.9994432330131531, 0.9994432330131531, 0.9994432330131531], [0.16898663341999054, 0.26197105646133423, 0.3346325159072876, 0.3950445353984833, 0.4768930971622467, 0.5718262791633606, 0.7110245227813721, 0.842706024646759, 0.9373608231544495, 0.9788418412208557, 0.993318498134613, 0.9974944591522217, 0.9994432330131531, 0.9997215867042542, 0.9997215867042542, 0.9994432330131531, 0.9997215867042542, 0.9997215867042542, 0.9997215867042542, 0.9997215867042542, 0.9994432330131531, 0.9994432330131531, 0.9997215867042542, 0.9997215867042542, 0.9997215867042542], [0.08101336658000946, 0.08602450042963028, 0.08630289882421494, 0.08184855431318283, 0.07795099914073944, 0.08518931269645691, 0.09131403267383575, 0.08491091430187225, 0.0846325159072876, 0.07795099914073944, 0.08769487589597702, 0.0846325159072876, 0.08853006362915039, 0.0826837420463562, 0.08157015591859818, 0.07739420980215073, 0.08741647750139236, 0.08546770364046097, 0.08936525881290436, 0.0871380865573883, 0.08880846202373505, 0.08853006362915039, 0.08129175752401352, 0.0846325159072876, 0.09075723588466644], [0.09855233877897263, 0.1909799575805664, 0.26308462023735046, 0.32655900716781616, 0.3883630335330963, 0.47856348752975464, 0.5698775053024292, 0.7126948833465576, 0.8619153499603271, 0.9468262791633606, 0.983574628829956, 0.9922049045562744, 0.9963808655738831, 0.9974944591522217, 0.9986079931259155, 0.9991648197174072, 0.9997215867042542, 0.9997215867042542, 0.9997215867042542, 0.9994432330131531, 0.9994432330131531, 0.9994432330131531, 0.9994432330131531, 0.9994432330131531, 0.9994432330131